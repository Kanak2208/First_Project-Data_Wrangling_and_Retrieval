# %%
import requests
import pandas as pd

url = "https://ghoapi.azureedge.net/api/NCD_BMI_30A?$top=1000"
data = requests.get(url).json()

# %%
data
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#NCD_BMI_30A',
#  'value': [{'Id': 21,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ESP',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1997,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '15.8 [14.5-17.1]',
#    'NumericValue': 15.764681,
#    'Low': 14.496294,
#    'High': 17.076965,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1997',
#    'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1997-12-31T00:00:00+01:00'},
#   {'Id': 235,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'WSM',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1991,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '38.8 [36.8-40.8]',
#    'NumericValue': 38.792646,
#    'Low': 36.772242,
#    'High': 40.815765,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1991',
#    'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1991-12-31T00:00:00+01:00'},
#   {'Id': 262,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BFA',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2000,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.9 [0.5-1.5]',
#    'NumericValue': 0.92653809,
#    'Low': 0.54648547,
#    'High': 1.4641713,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2000',
#    'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2000-12-31T00:00:00+01:00'},
#   {'Id': 363,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IDN',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1992,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.6 [2.0-3.3]',
#    'NumericValue': 2.5925873,
#    'Low': 2.0080164,
#    'High': 3.2806724,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1992',
#    'TimeDimensionBegin': '1992-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1992-12-31T00:00:00+01:00'},
#   {'Id': 390,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LBN',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2021,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '28.3 [23.3-33.9]',
#    'NumericValue': 28.336504,
#    'Low': 23.259968,
#    'High': 33.859724,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2021',
#    'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2021-12-31T00:00:00+01:00'},
#   {'Id': 750,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRN',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2006,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '18.3 [15.7-21.2]',
#    'NumericValue': 18.341002,
#    'Low': 15.729658,
#    'High': 21.161823,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2006',
#    'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2006-12-31T00:00:00+01:00'},
#   {'Id': 2094,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NLD',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1996,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '9.9 [9.0-10.8]',
#    'NumericValue': 9.8836593,
#    'Low': 8.9976959,
#    'High': 10.810543,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1996',
#    'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1996-12-31T00:00:00+01:00'},
#   {'Id': 2305,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KNA',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2011,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '45.6 [37.8-53.4]',
#    'NumericValue': 45.550391,
#    'Low': 37.797081,
#    'High': 53.417659,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2011',
#    'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2011-12-31T00:00:00+01:00'},
#   {'Id': 2346,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KEN',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2000,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.2 [1.2-3.5]',
#    'NumericValue': 2.1721505,
#    'Low': 1.2296134,
#    'High': 3.5213124,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2000',
#    'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2000-12-31T00:00:00+01:00'},
#   {'Id': 3050,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NIC',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2014,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '33.5 [29.8-37.2]',
#    'NumericValue': 33.501524,
#    'Low': 29.839551,
#    'High': 37.168866,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 3259,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ETH',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1994,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.2 [0.1-0.4]',
#    'NumericValue': 0.23046781,
#    'Low': 0.1059488,
#    'High': 0.43723639,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1994',
#    'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1994-12-31T00:00:00+01:00'},
#   {'Id': 3404,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRN',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2009,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '22.4 [19.0-26.0]',
#    'NumericValue': 22.376193,
#    'Low': 18.985343,
#    'High': 26.042566,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2009',
#    'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2009-12-31T00:00:00+01:00'},
#   {'Id': 3671,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NLD',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2015,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '13.5 [11.2-16.1]',
#    'NumericValue': 13.522819,
#    'Low': 11.197498,
#    'High': 16.109467,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 3976,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BLR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '23.1 [17.6-29.1]',
#    'NumericValue': 23.064324,
#    'Low': 17.592852,
#    'High': 29.096746,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 4130,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'VUT',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1996,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '15.2 [13.3-17.3]',
#    'NumericValue': 15.233731,
#    'Low': 13.313037,
#    'High': 17.291351,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1996',
#    'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1996-12-31T00:00:00+01:00'},
#   {'Id': 4691,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2000,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '11.8 [10.8-12.9]',
#    'NumericValue': 11.81226,
#    'Low': 10.788686,
#    'High': 12.883335,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2000',
#    'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2000-12-31T00:00:00+01:00'},
#   {'Id': 5029,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NZL',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1990,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '14.3 [12.4-16.3]',
#    'NumericValue': 14.298415,
#    'Low': 12.41487,
#    'High': 16.252132,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1990',
#    'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1990-12-31T00:00:00+01:00'},
#   {'Id': 5041,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PER',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1991,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '5.3 [3.3-8.0]',
#    'NumericValue': 5.3213976,
#    'Low': 3.2828253,
#    'High': 7.9705104,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1991',
#    'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1991-12-31T00:00:00+01:00'},
#   {'Id': 5484,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KWT',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1993,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '30.0 [27.6-32.4]',
#    'NumericValue': 30.019465,
#    'Low': 27.640933,
#    'High': 32.367927,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1993',
#    'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1993-12-31T00:00:00+01:00'},
#   {'Id': 7292,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GNB',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2003,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '6.6 [4.8-8.9]',
#    'NumericValue': 6.6397846,
#    'Low': 4.7922585,
#    'High': 8.8601574,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'},
#   {'Id': 8493,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SVN',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2008,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '13.7 [13.0-14.5]',
#    'NumericValue': 13.730013,
#    'Low': 13.002245,
#    'High': 14.474218,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2008',
#    'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2008-12-31T00:00:00+01:00'},
#   {'Id': 8951,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BLZ',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2000,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '25.6 [22.4-29.1]',
#    'NumericValue': 25.5968,
#    'Low': 22.391944,
#    'High': 29.085422,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2000',
#    'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2000-12-31T00:00:00+01:00'},
#   {'Id': 9121,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NAM',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2013,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '14.3 [12.5-16.1]',
#    'NumericValue': 14.267106,
#    'Low': 12.532981,
#    'High': 16.139263,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2013',
#    'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2013-12-31T00:00:00+01:00'},
#   {'Id': 10286,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ERI',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2016,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.4 [2.5-4.4]',
#    'NumericValue': 3.3566196,
#    'Low': 2.4742221,
#    'High': 4.4212636,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 11063,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ZMB',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2017,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '13.0 [11.1-15.1]',
#    'NumericValue': 13.039796,
#    'Low': 11.108397,
#    'High': 15.058622,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2017',
#    'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2017-12-31T00:00:00+01:00'},
#   {'Id': 11600,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GRD',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2002,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '9.7 [6.6-13.4]',
#    'NumericValue': 9.6611395,
#    'Low': 6.6269219,
#    'High': 13.436636,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2002',
#    'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2002-12-31T00:00:00+01:00'},
#   {'Id': 11670,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MAR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1990,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '4.2 [2.6-6.4]',
#    'NumericValue': 4.224021,
#    'Low': 2.5692806,
#    'High': 6.4495109,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1990',
#    'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1990-12-31T00:00:00+01:00'},
#   {'Id': 12750,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IND',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'SEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1996,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.9 [1.6-2.1]',
#    'NumericValue': 1.8558508,
#    'Low': 1.6138868,
#    'High': 2.1248363,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1996',
#    'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1996-12-31T00:00:00+01:00'},
#   {'Id': 13288,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HRV',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2015,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '25.1 [23.3-27.0]',
#    'NumericValue': 25.097725,
#    'Low': 23.272026,
#    'High': 26.978004,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 14139,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'JOR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1995,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '26.4 [24.3-28.6]',
#    'NumericValue': 26.393545,
#    'Low': 24.253523,
#    'High': 28.614804,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1995',
#    'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1995-12-31T00:00:00+01:00'},
#   {'Id': 14794,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SYR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1995,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '27.0 [22.7-31.6]',
#    'NumericValue': 27.007559,
#    'Low': 22.66905,
#    'High': 31.603491,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1995',
#    'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1995-12-31T00:00:00+01:00'},
#   {'Id': 15359,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MYS',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2012,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '19.5 [18.1-20.9]',
#    'NumericValue': 19.486509,
#    'Low': 18.140502,
#    'High': 20.889911,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 15383,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SVK',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2009,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '17.8 [15.9-19.8]',
#    'NumericValue': 17.784464,
#    'Low': 15.864407,
#    'High': 19.778956,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2009',
#    'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2009-12-31T00:00:00+01:00'},
#   {'Id': 15770,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRB',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2012,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '20.8 [17.0-24.8]',
#    'NumericValue': 20.802629,
#    'Low': 16.966379,
#    'High': 24.79807,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 16421,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SAU',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2009,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '33.1 [31.7-34.6]',
#    'NumericValue': 33.127406,
#    'Low': 31.701654,
#    'High': 34.604177,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2009',
#    'TimeDimensionBegin': '2009-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2009-12-31T00:00:00+01:00'},
#   {'Id': 17030,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NRU',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2015,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.4 [65.4-73.4]',
#    'NumericValue': 69.435555,
#    'Low': 65.364438,
#    'High': 73.432434,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 17142,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARG',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1993,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '14.2 [11.3-17.5]',
#    'NumericValue': 14.200072,
#    'Low': 11.322872,
#    'High': 17.483398,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1993',
#    'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1993-12-31T00:00:00+01:00'},
#   {'Id': 17215,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GEO',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2002,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '19.9 [17.1-22.9]',
#    'NumericValue': 19.936077,
#    'Low': 17.128463,
#    'High': 22.880335,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2002',
#    'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2002-12-31T00:00:00+01:00'},
#   {'Id': 17800,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MDA',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2013,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '26.3 [24.0-28.6]',
#    'NumericValue': 26.348504,
#    'Low': 24.00261,
#    'High': 28.631252,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2013',
#    'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2013-12-31T00:00:00+01:00'},
#   {'Id': 18843,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MAR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2022,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '30.2 [25.4-35.3]',
#    'NumericValue': 30.167252,
#    'Low': 25.359961,
#    'High': 35.267258,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2022',
#    'TimeDimensionBegin': '2022-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2022-12-31T00:00:00+01:00'},
#   {'Id': 18893,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PRK',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'SEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1990,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.9 [0.9-6.6]',
#    'NumericValue': 2.8873658,
#    'Low': 0.85670548,
#    'High': 6.6364229,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1990',
#    'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1990-12-31T00:00:00+01:00'},
#   {'Id': 19322,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ROU',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2016,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '25.1 [22.6-27.7]',
#    'NumericValue': 25.106236,
#    'Low': 22.649467,
#    'High': 27.677387,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 19376,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LBY',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2011,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '22.3 [18.6-26.2]',
#    'NumericValue': 22.301237,
#    'Low': 18.552668,
#    'High': 26.249063,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2011',
#    'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2011-12-31T00:00:00+01:00'},
#   {'Id': 19409,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#    'SpatialDim': 'WB_LI',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': None,
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1999,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '4.6 [4.1-5.2]',
#    'NumericValue': 4.5614887,
#    'Low': 4.0677439,
#    'High': 5.198177,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1999',
#    'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1999-12-31T00:00:00+01:00'},
#   {'Id': 19824,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MYS',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1994,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '8.7 [7.3-10.5]',
#    'NumericValue': 8.7358549,
#    'Low': 7.2511107,
#    'High': 10.455152,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1994',
#    'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1994-12-31T00:00:00+01:00'},
#   {'Id': 19831,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'QAT',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2012,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.8 [40.1-47.5]',
#    'NumericValue': 43.762907,
#    'Low': 40.112865,
#    'High': 47.460297,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 19932,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'THA',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'SEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2022,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '12.2 [9.7-15.1]',
#    'NumericValue': 12.185579,
#    'Low': 9.6872866,
#    'High': 15.088683,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2022',
#    'TimeDimensionBegin': '2022-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2022-12-31T00:00:00+01:00'},
#   {'Id': 20389,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1997,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '15.0 [11.6-18.6]',
#    'NumericValue': 14.953201,
#    'Low': 11.639153,
#    'High': 18.596317,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1997',
#    'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1997-12-31T00:00:00+01:00'},
#   {'Id': 20703,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRB',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1995,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '10.4 [8.5-12.7]',
#    'NumericValue': 10.449657,
#    'Low': 8.4630124,
#    'High': 12.726644,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1995',
#    'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1995-12-31T00:00:00+01:00'},
#   {'Id': 21210,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GUY',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2003,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '15.9 [13.6-18.4]',
#    'NumericValue': 15.940037,
#    'Low': 13.630247,
#    'High': 18.372338,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'},
#   {'Id': 21371,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LBY',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2005,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '37.5 [33.2-41.8]',
#    'NumericValue': 37.516037,
#    'Low': 33.19495,
#    'High': 41.778672,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 21979,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MKD',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2012,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '20.7 [11.7-31.5]',
#    'NumericValue': 20.735496,
#    'Low': 11.706504,
#    'High': 31.529307,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 22188,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TON',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1996,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.8 [55.0-66.4]',
#    'NumericValue': 60.773855,
#    'Low': 54.953998,
#    'High': 66.425294,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1996',
#    'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1996-12-31T00:00:00+01:00'},
#   {'Id': 22258,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COK',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.3 [54.5-64.0]',
#    'NumericValue': 59.294397,
#    'Low': 54.459149,
#    'High': 63.95604,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 22908,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NIC',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1994,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '15.6 [12.7-19.1]',
#    'NumericValue': 15.609941,
#    'Low': 12.716301,
#    'High': 19.075382,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1994',
#    'TimeDimensionBegin': '1994-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1994-12-31T00:00:00+01:00'},
#   {'Id': 24306,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2011,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '19.6 [17.2-22.1]',
#    'NumericValue': 19.592112,
#    'Low': 17.222522,
#    'High': 22.073835,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2011',
#    'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2011-12-31T00:00:00+01:00'},
#   {'Id': 24424,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ROU',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2010,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '19.7 [18.0-21.7]',
#    'NumericValue': 19.747606,
#    'Low': 17.953308,
#    'High': 21.667837,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2010',
#    'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2010-12-31T00:00:00+01:00'},
#   {'Id': 25137,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HTI',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2000,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '5.5 [4.4-6.8]',
#    'NumericValue': 5.4660268,
#    'Low': 4.3859765,
#    'High': 6.8466648,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2000',
#    'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2000-12-31T00:00:00+01:00'},
#   {'Id': 25330,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TKL',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1990,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '53.5 [47.4-59.6]',
#    'NumericValue': 53.490645,
#    'Low': 47.381359,
#    'High': 59.551722,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1990',
#    'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1990-12-31T00:00:00+01:00'},
#   {'Id': 25600,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRL',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2019,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '27.3 [24.4-30.3]',
#    'NumericValue': 27.298057,
#    'Low': 24.407223,
#    'High': 30.347991,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 26322,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'GLOBAL',
#    'SpatialDim': 'GLOBAL',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': None,
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2006,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '8.5 [8.3-8.6]',
#    'NumericValue': 8.492306,
#    'Low': 8.338768,
#    'High': 8.649747,
#    'Comments': None,
#    'Date': '2024-05-23T13:35:20.483+02:00',
#    'TimeDimensionValue': '2006',
#    'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2006-12-31T00:00:00+01:00'},
#   {'Id': 26998,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'REGION',
#    'SpatialDim': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': None,
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1998,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.8 [1.7-2.0]',
#    'NumericValue': 1.845173,
#    'Low': 1.703709,
#    'High': 2.001671,
#    'Comments': None,
#    'Date': '2024-05-23T13:35:20.483+02:00',
#    'TimeDimensionValue': '1998',
#    'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1998-12-31T00:00:00+01:00'},
#   {'Id': 27929,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'REGION',
#    'SpatialDim': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': None,
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2005,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '20.3 [19.9-20.8]',
#    'NumericValue': 20.306771,
#    'Low': 19.880888,
#    'High': 20.755854,
#    'Comments': None,
#    'Date': '2024-05-23T13:35:20.483+02:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 28219,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CHE',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2021,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '14.6 [12.2-17.1]',
#    'NumericValue': 14.553553,
#    'Low': 12.185118,
#    'High': 17.088722,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2021',
#    'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2021-12-31T00:00:00+01:00'},
#   {'Id': 29198,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HND',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2007,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '19.2 [16.1-23.0]',
#    'NumericValue': 19.231068,
#    'Low': 16.125599,
#    'High': 22.979017,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2007',
#    'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2007-12-31T00:00:00+01:00'},
#   {'Id': 29313,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KNA',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
# ...
#    'SpatialDim': 'DMA',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2021,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.9 [34.7-53.2]',
#    'NumericValue': 43.883094,
#    'Low': 34.738371,
#    'High': 53.212738,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2021',
#    'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2021-12-31T00:00:00+01:00'},
#   {'Id': 471462,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRL',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1991,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '13.7 [10.6-17.2]',
#    'NumericValue': 13.670775,
#    'Low': 10.591409,
#    'High': 17.223848,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1991',
#    'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1991-12-31T00:00:00+01:00'},
#   {'Id': 472119,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TLS',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'SEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2010,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.0 [0.8-1.2]',
#    'NumericValue': 0.9940898,
#    'Low': 0.77995402,
#    'High': 1.246238,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2010',
#    'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2010-12-31T00:00:00+01:00'},
#   {'Id': 472297,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'VEN',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2022,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '20.2 [16.0-24.5]',
#    'NumericValue': 20.212513,
#    'Low': 16.027585,
#    'High': 24.544083,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2022',
#    'TimeDimensionBegin': '2022-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2022-12-31T00:00:00+01:00'},
#   {'Id': 472313,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MLT',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2016,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '33.2 [28.4-38.2]',
#    'NumericValue': 33.17591,
#    'Low': 28.352889,
#    'High': 38.212749,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 472546,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DNK',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1998,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '9.1 [7.9-10.3]',
#    'NumericValue': 9.0589471,
#    'Low': 7.8795135,
#    'High': 10.290846,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1998',
#    'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1998-12-31T00:00:00+01:00'},
#   {'Id': 472653,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'YEM',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1997,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.3 [2.3-4.7]',
#    'NumericValue': 3.3331916,
#    'Low': 2.2525899,
#    'High': 4.702498,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1997',
#    'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1997-12-31T00:00:00+01:00'},
#   {'Id': 472764,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CAN',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2007,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '22.7 [21.2-24.2]',
#    'NumericValue': 22.714606,
#    'Low': 21.241415,
#    'High': 24.220157,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2007',
#    'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2007-12-31T00:00:00+01:00'},
#   {'Id': 473103,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LCA',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2019,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '18.2 [15.2-21.4]',
#    'NumericValue': 18.238294,
#    'Low': 15.164423,
#    'High': 21.43141,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 473864,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COG',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1998,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '7.1 [5.7-8.7]',
#    'NumericValue': 7.0919409,
#    'Low': 5.7261296,
#    'High': 8.6535394,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1998',
#    'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1998-12-31T00:00:00+01:00'},
#   {'Id': 473992,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'EST',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1995,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '12.6 [10.7-14.7]',
#    'NumericValue': 12.643287,
#    'Low': 10.671438,
#    'High': 14.674896,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1995',
#    'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1995-12-31T00:00:00+01:00'},
#   {'Id': 474063,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PRI',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '29.3 [25.3-33.7]',
#    'NumericValue': 29.321539,
#    'Low': 25.293481,
#    'High': 33.71385,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 474318,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NIU',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'WPR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2006,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.8 [48.8-60.8]',
#    'NumericValue': 54.818654,
#    'Low': 48.792103,
#    'High': 60.793376,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2006',
#    'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2006-12-31T00:00:00+01:00'},
#   {'Id': 475612,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GRC',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2020,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '28.0 [24.2-32.0]',
#    'NumericValue': 27.979678,
#    'Low': 24.157745,
#    'High': 32.033581,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 476957,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SLV',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AMR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2010,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '24.1 [22.1-26.2]',
#    'NumericValue': 24.089871,
#    'Low': 22.09511,
#    'High': 26.206043,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2010',
#    'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2010-12-31T00:00:00+01:00'},
#   {'Id': 477497,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CAF',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1991,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.2 [1.4-3.2]',
#    'NumericValue': 2.1575561,
#    'Low': 1.3535126,
#    'High': 3.2337386,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1991',
#    'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1991-12-31T00:00:00+01:00'},
#   {'Id': 477504,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GBR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2016,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '24.7 [23.7-25.8]',
#    'NumericValue': 24.745297,
#    'Low': 23.731227,
#    'High': 25.792667,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 477936,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'REGION',
#    'SpatialDim': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': None,
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1991,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '6.5 [5.6-7.3]',
#    'NumericValue': 6.470013,
#    'Low': 5.637797,
#    'High': 7.34864,
#    'Comments': None,
#    'Date': '2024-05-23T13:35:20.483+02:00',
#    'TimeDimensionValue': '1991',
#    'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1991-12-31T00:00:00+01:00'},
#   {'Id': 478776,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GRC',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EUR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1995,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '16.5 [14.1-18.9]',
#    'NumericValue': 16.499002,
#    'Low': 14.143807,
#    'High': 18.936639,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1995',
#    'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1995-12-31T00:00:00+01:00'},
#   {'Id': 478969,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BDI',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1998,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.4 [0.8-2.5]',
#    'NumericValue': 1.3808423,
#    'Low': 0.75458712,
#    'High': 2.4557861,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1998',
#    'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1998-12-31T00:00:00+01:00'},
#   {'Id': 479010,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'JOR',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'EMR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1991,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '24.0 [21.3-26.7]',
#    'NumericValue': 23.960726,
#    'Low': 21.29309,
#    'High': 26.691407,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1991',
#    'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1991-12-31T00:00:00+01:00'},
#   {'Id': 479411,
#    'IndicatorCode': 'NCD_BMI_30A',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ZAF',
#    'TimeDimType': 'YEAR',
#    'ParentLocationCode': 'AFR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2003,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS18-PLUS',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '24.7 [23.5-25.9]',
#    'NumericValue': 24.693684,
#    'Low': 23.502071,
#    'High': 25.945532,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'}]}

# %%
data.keys()
# Out:
# dict_keys(['@odata.context', 'value'])

# %%
obesity_df = pd.DataFrame(data["value"])
obesity_df
# Out:
#          Id IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0        21   NCD_BMI_30A        COUNTRY        ESP        YEAR
# 1       235   NCD_BMI_30A        COUNTRY        WSM        YEAR
# 2       262   NCD_BMI_30A        COUNTRY        BFA        YEAR
# 3       363   NCD_BMI_30A        COUNTRY        IDN        YEAR
# 4       390   NCD_BMI_30A        COUNTRY        LBN        YEAR
# ..      ...           ...            ...        ...         ...
# 995  477936   NCD_BMI_30A         REGION        EMR        YEAR
# 996  478776   NCD_BMI_30A        COUNTRY        GRC        YEAR
# 997  478969   NCD_BMI_30A        COUNTRY        BDI        YEAR
# 998  479010   NCD_BMI_30A        COUNTRY        JOR        YEAR
# 999  479411   NCD_BMI_30A        COUNTRY        ZAF        YEAR
#
#     ParentLocationCode         ParentLocation Dim1Type      Dim1  TimeDim  \
# 0                  EUR                 Europe      SEX   SEX_MLE     1997
# 1                  WPR        Western Pacific      SEX  SEX_BTSX     1991
# 2                  AFR                 Africa      SEX   SEX_MLE     2000
# 3                  WPR        Western Pacific      SEX  SEX_FMLE     1992
# 4                  EMR  Eastern Mediterranean      SEX   SEX_MLE     2021
# ..                 ...                    ...      ...       ...      ...
# 995               None                   None      SEX   SEX_MLE     1991
# 996                EUR                 Europe      SEX  SEX_BTSX     1995
# 997                AFR                 Africa      SEX  SEX_BTSX     1998
# 998                EMR  Eastern Mediterranean      SEX  SEX_BTSX     1991
# 999                AFR                 Africa      SEX  SEX_BTSX     2003
#
#      ... DataSourceDim             Value NumericValue        Low       High  \
# 0    ...          None  15.8 [14.5-17.1]    15.764681  14.496294  17.076965
# 1    ...          None  38.8 [36.8-40.8]    38.792646  36.772242  40.815765
# 2    ...          None     0.9 [0.5-1.5]     0.926538   0.546485   1.464171
# 3    ...          None     2.6 [2.0-3.3]     2.592587   2.008016   3.280672
# 4    ...          None  28.3 [23.3-33.9]    28.336504  23.259968  33.859724
# ..   ...           ...               ...          ...        ...        ...
# 995  ...          None     6.5 [5.6-7.3]     6.470013   5.637797   7.348640
# 996  ...          None  16.5 [14.1-18.9]    16.499002  14.143807  18.936639
# 997  ...          None     1.4 [0.8-2.5]     1.380842   0.754587   2.455786
# 998  ...          None  24.0 [21.3-26.7]    23.960726  21.293090  26.691407
# 999  ...          None  24.7 [23.5-25.9]    24.693684  23.502071  25.945532
#
#     Comments                           Date  TimeDimensionValue  \
# 0       None  2024-02-29T16:06:41.017+01:00                1997
# 1       None  2024-02-29T16:06:41.017+01:00                1991
# 2       None  2024-02-29T16:06:41.017+01:00                2000
# 3       None  2024-02-29T16:06:41.017+01:00                1992
# 4       None  2024-02-29T16:06:41.017+01:00                2021
# ..       ...                            ...                 ...
# 995     None  2024-05-23T13:35:20.483+02:00                1991
# 996     None  2024-02-29T16:06:41.017+01:00                1995
# 997     None  2024-02-29T16:06:41.017+01:00                1998
# 998     None  2024-02-29T16:06:41.017+01:00                1991
# 999     None  2024-02-29T16:06:41.017+01:00                2003
#
#             TimeDimensionBegin           TimeDimensionEnd
# 0    1997-01-01T00:00:00+01:00  1997-12-31T00:00:00+01:00
# 1    1991-01-01T00:00:00+01:00  1991-12-31T00:00:00+01:00
# 2    2000-01-01T00:00:00+01:00  2000-12-31T00:00:00+01:00
# 3    1992-01-01T00:00:00+01:00  1992-12-31T00:00:00+01:00
# 4    2021-01-01T00:00:00+01:00  2021-12-31T00:00:00+01:00
# ..                         ...                        ...
# 995  1991-01-01T00:00:00+01:00  1991-12-31T00:00:00+01:00
# 996  1995-01-01T00:00:00+01:00  1995-12-31T00:00:00+01:00
# 997  1998-01-01T00:00:00+01:00  1998-12-31T00:00:00+01:00
# 998  1991-01-01T00:00:00+01:00  1991-12-31T00:00:00+01:00
# 999  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00
#
# [1000 rows x 25 columns]

# %%
obesity_df.columns
# Out:
# Index(['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim', 'TimeDimType',
#        'ParentLocationCode', 'ParentLocation', 'Dim1Type', 'Dim1', 'TimeDim',
#        'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType',
#        'DataSourceDim', 'Value', 'NumericValue', 'Low', 'High', 'Comments',
#        'Date', 'TimeDimensionValue', 'TimeDimensionBegin', 'TimeDimensionEnd'],
#       dtype='object')

# %%
obesity_df.ParentLocation.unique()
# Out:
# array(['Europe', 'Western Pacific', 'Africa', 'Eastern Mediterranean',
#        'Americas', 'South-East Asia', None], dtype=object)

# %%
df_obesity = obesity_df[['ParentLocation', 'TimeDim', 'Dim1', 'Value']]
df_obesity.head()
# Out:
#           ParentLocation  TimeDim      Dim1             Value
# 0                 Europe     1997   SEX_MLE  15.8 [14.5-17.1]
# 1        Western Pacific     1991  SEX_BTSX  38.8 [36.8-40.8]
# 2                 Africa     2000   SEX_MLE     0.9 [0.5-1.5]
# 3        Western Pacific     1992  SEX_FMLE     2.6 [2.0-3.3]
# 4  Eastern Mediterranean     2021   SEX_MLE  28.3 [23.3-33.9]

# %%
df_obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ParentLocation  949 non-null    object
#  1   TimeDim         1000 non-null   int64
#  2   Dim1            1000 non-null   object
#  3   Value           1000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 31.4+ KB

# %%
df_obesity.rename(columns={'ParentLocation': 'continent'}, inplace=True)
df_obesity.rename(columns={'TimeDim': 'year'}, inplace=True)
df_obesity.rename(columns={'Dim1': 'gender'}, inplace=True)
df_obesity.rename(columns={'Value': 'BMI'}, inplace=True)
# Out:
# /tmp/ipython-input-182/2067643706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesity.rename(columns={'ParentLocation': 'continent'}, inplace=True)
# /tmp/ipython-input-182/2067643706.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesity.rename(columns={'TimeDim': 'year'}, inplace=True)
# /tmp/ipython-input-182/2067643706.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesity.rename(columns={'Dim1': 'gender'}, inplace=True)
# /tmp/ipython-input-182/2067643706.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesity.rename(columns={'Value': 'BMI'}, inplace=True)

# %%
df_obesity.columns
# Out:
# Index(['continent', 'year', 'gender', 'BMI'], dtype='object')

# %%
df_obesity.gender.unique()
# Out:
# array(['SEX_MLE', 'SEX_BTSX', 'SEX_FMLE'], dtype=object)

# %%
df_obesity['gender'] = df_obesity['gender'].replace({'SEX_MLE': 'M', 'SEX_BTSX': 'N', 'SEX_FMLE': 'F'})
df_obesity
# Out:
# /tmp/ipython-input-182/1708789252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesity['gender'] = df_obesity['gender'].replace({'SEX_MLE': 'M', 'SEX_BTSX': 'N', 'SEX_FMLE': 'F'})
#                  continent  year gender               BMI
# 0                   Europe  1997      M  15.8 [14.5-17.1]
# 1          Western Pacific  1991      N  38.8 [36.8-40.8]
# 2                   Africa  2000      M     0.9 [0.5-1.5]
# 3          Western Pacific  1992      F     2.6 [2.0-3.3]
# 4    Eastern Mediterranean  2021      M  28.3 [23.3-33.9]
# ..                     ...   ...    ...               ...
# 995                   None  1991      M     6.5 [5.6-7.3]
# 996                 Europe  1995      N  16.5 [14.1-18.9]
# 997                 Africa  1998      N     1.4 [0.8-2.5]
# 998  Eastern Mediterranean  1991      N  24.0 [21.3-26.7]
# 999                 Africa  2003      N  24.7 [23.5-25.9]
#
# [1000 rows x 4 columns]

# %%
df_obesity['BMI'] = df_obesity['BMI'].astype(str).str.extract(r'^(\d+\.?\d*)')
df_obesity.head()
# Out:
# /tmp/ipython-input-182/3850775468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesity['BMI'] = df_obesity['BMI'].astype(str).str.extract(r'^(\d+\.?\d*)')
#                continent  year gender   BMI
# 0                 Europe  1997      M  15.8
# 1        Western Pacific  1991      N  38.8
# 2                 Africa  2000      M   0.9
# 3        Western Pacific  1992      F   2.6
# 4  Eastern Mediterranean  2021      M  28.3

# %%
df_obesity['BMI'] = df_obesity['BMI'].astype(float)
df_obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   continent  949 non-null    object
#  1   year       1000 non-null   int64
#  2   gender     1000 non-null   object
#  3   BMI        1000 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 31.4+ KB
# /tmp/ipython-input-182/2081027504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesity['BMI'] = df_obesity['BMI'].astype(float)

# %%
df_obesity.head(10)
# Out:
#                continent  year gender   BMI
# 0                 Europe  1997      M  15.8
# 1        Western Pacific  1991      N  38.8
# 2                 Africa  2000      M   0.9
# 3        Western Pacific  1992      F   2.6
# 4  Eastern Mediterranean  2021      M  28.3
# 5        Western Pacific  2006      N  18.3
# 6                 Europe  1996      N   9.9
# 7               Americas  2011      F  45.6
# 8                 Africa  2000      M   2.2
# 9               Americas  2014      F  33.5

# %%
df_obesity.isna().sum()
# Out:
# continent    51
# year          0
# gender        0
# BMI           0
# dtype: int64

# %%
df_obesity.dropna(subset=['continent'], inplace=True)
# Out:
# /tmp/ipython-input-182/112221948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesity.dropna(subset=['continent'], inplace=True)

# %%
df_obesity.isna().sum()
# Out:
# continent    0
# year         0
# gender       0
# BMI          0
# dtype: int64

# %%
df_obesity.shape
# Out:
# (949, 4)

# %%
df_obesity.duplicated().sum()
# Out:
# np.int64(8)

# %%
df_obesity = df_obesity.drop_duplicates()

# %%
df_obesity.shape
# Out:
# (941, 4)

# %%
df_obesity
# Out:
#                  continent  year gender   BMI
# 0                   Europe  1997      M  15.8
# 1          Western Pacific  1991      N  38.8
# 2                   Africa  2000      M   0.9
# 3          Western Pacific  1992      F   2.6
# 4    Eastern Mediterranean  2021      M  28.3
# ..                     ...   ...    ...   ...
# 994                 Europe  2016      M  24.7
# 996                 Europe  1995      N  16.5
# 997                 Africa  1998      N   1.4
# 998  Eastern Mediterranean  1991      N  24.0
# 999                 Africa  2003      N  24.7
#
# [941 rows x 4 columns]

# %%
import pandas as pd


url = "https://docs.google.com/spreadsheets/d/1iNp4gN_YY8yn1SwEdnfx0nD1gWGBSwhc0fE9TqXzX_I/export?format=csv"

df = pd.read_csv(url)
df.head()
# Out:
#          City  Rank Sunshine hours(City) Cost of a bottle of water(City)  \
# 0   Amsterdam     1                 1858                           £1.92
# 1      Sydney     2                 2636                           £1.48
# 2      Vienna     3                 1884                           £1.94
# 3   Stockholm     4                 1821                           £1.72
# 4  Copenhagen     5                 1630                           £2.19
#
#   Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0                  20.40%                              81.2
# 1                  29.00%                              82.1
# 2                  20.10%                              81.0
# 3                  20.60%                              81.8
# 4                  19.70%                              79.8
#
#   Pollution(Index score) (City) Annual avg. hours worked  \
# 0                         30.93                     1434
# 1                         26.86                     1712
# 2                         17.33                     1501
# 3                         19.63                     1452
# 4                         21.24                     1380
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 0                       7.44                       422
# 1                       7.22                       406
# 2                       7.29                       132
# 3                       7.35                       129
# 4                       7.64                       154
#
#    Number of take out places(City) Cost of a monthly gym membership(City)
# 0                             1048                                 £34.90
# 1                             1103                                 £41.66
# 2                             1008                                 £25.74
# 3                              598                                 £37.31
# 4                              523                                 £32.53

# %%
df.columns
# Out:
# Index(['City', 'Rank', 'Sunshine hours(City)',
#        'Cost of a bottle of water(City)', 'Obesity levels(Country)',
#        'Life expectancy(years) (Country)', 'Pollution(Index score) (City)',
#        'Annual avg. hours worked', 'Happiness levels(Country)',
#        'Outdoor activities(City)', 'Number of take out places(City)',
#        'Cost of a monthly gym membership(City)'],
#       dtype='object')

# %%
df = df.drop(columns=['Rank','Sunshine hours(City)','Cost of a bottle of water(City)','Pollution(Index score) (City)', 'Annual avg. hours worked', 'Outdoor activities(City)', 'Number of take out places(City)' ])

# %%
df.columns
# Out:
# Index(['City', 'Obesity levels(Country)', 'Life expectancy(years) (Country)',
#        'Happiness levels(Country)', 'Cost of a monthly gym membership(City)'],
#       dtype='object')

# %%
df["City"].unique()
# Out:
# array(['Amsterdam', 'Sydney', 'Vienna', 'Stockholm', 'Copenhagen',
#        'Helsinki', 'Fukuoka', 'Berlin', 'Barcelona', 'Vancouver',
#        'Melbourne', 'Beijing', 'Bangkok', 'Buenos Aires', 'Toronto',
#        'Madrid', 'Jakarta', 'Seoul', 'Frankfurt', 'Geneva', 'Tel Aviv',
#        'Istanbul', 'Cairo', 'Taipei', 'Los Angeles', 'Mumbai', 'Boston',
#        'Dublin', 'Tokyo', 'Chicago', 'Hong Kong', 'Shanghai', 'Brussels',
#        'San Francisco', 'Paris', 'Sao Paulo', 'Zurich', 'London',
#        'Johannesburg', 'Milan', 'Washington, D.C.', 'New York', 'Moscow',
#        'Mexico City'], dtype=object)

# %%
city_to_continent = {
    "Amsterdam": "Europe",
    "Sydney": "Australia",
    "Vienna": "Europe",
    "Stockholm": "Europe",
    "Copenhagen": "Europe",
    "Helsinki": "Europe",
    "Fukuoka": "Asia",
    "Berlin": "Europe",
    "Barcelona": "Europe",
    "Vancouver": "North America",
    "Melbourne": "Australia",
    "Beijing": "Asia",
    "Bangkok": "Asia",
    "Buenos Aires": "South America",
    "Toronto": "North America",
    "Madrid": "Europe",
    "Jakarta": "Asia",
    "Seoul": "Asia",
    "Frankfurt": "Europe",
    "Geneva": "Europe",
    "Tel Aviv": "Asia",
    "Istanbul": "Europe/Asia",
    "Cairo": "Africa",
    "Taipei": "Asia",
    "Los Angeles": "North America",
    "Mumbai": "Asia",
    "Boston": "North America",
    "Dublin": "Europe",
    "Tokyo": "Asia",
    "Chicago": "North America",
    "Hong Kong": "Asia",
    "Shanghai": "Asia",
    "Brussels": "Europe",
    "San Francisco": "North America",
    "Paris": "Europe",
    "Sao Paulo": "South America",
    "Zurich": "Europe",
    "London": "Europe",
    "Johannesburg": "Africa",
    "Milan": "Europe",
    "Washington, D.C.": "North America",
    "New York": "North America",
    "Moscow": "Europe",
    "Mexico City": "North America"
}

# %%
df["Continent"] = df["City"].map(city_to_continent)

# %%
df
# Out:
#                 City Obesity levels(Country)  \
# 0          Amsterdam                  20.40%
# 1             Sydney                  29.00%
# 2             Vienna                  20.10%
# 3          Stockholm                  20.60%
# 4         Copenhagen                  19.70%
# 5           Helsinki                  22.20%
# 6            Fukuoka                   4.30%
# 7             Berlin                  22.30%
# 8          Barcelona                  23.80%
# 9          Vancouver                  29.40%
# 10         Melbourne                  29.00%
# 11           Beijing                   6.20%
# 12           Bangkok                  10.00%
# 13      Buenos Aires                  28.30%
# 14           Toronto                  29.40%
# 15            Madrid                  23.80%
# 16           Jakarta                   6.90%
# 17             Seoul                   4.70%
# 18         Frankfurt                  22.30%
# 19            Geneva                  19.50%
# 20          Tel Aviv                  26.10%
# 21          Istanbul                  32.10%
# 22             Cairo                  32.00%
# 23            Taipei                   6.20%
# 24       Los Angeles                  36.20%
# 25            Mumbai                   3.90%
# 26            Boston                  36.20%
# 27            Dublin                  25.30%
# 28             Tokyo                   4.30%
# 29           Chicago                  36.20%
# 30         Hong Kong                   6.20%
# 31          Shanghai                   6.20%
# 32          Brussels                  22.10%
# 33     San Francisco                  36.20%
# 34             Paris                  21.60%
# 35         Sao Paulo                  22.10%
# 36            Zurich                  19.50%
# 37            London                  27.80%
# 38      Johannesburg                  28.30%
# 39             Milan                  19.90%
# 40  Washington, D.C.                  36.20%
# 41          New York                  36.20%
# 42            Moscow                  23.10%
# 43       Mexico City                  28.90%
#
#     Life expectancy(years) (Country)  Happiness levels(Country)  \
# 0                               81.2                       7.44
# 1                               82.1                       7.22
# 2                               81.0                       7.29
# 3                               81.8                       7.35
# 4                               79.8                       7.64
# 5                               80.4                       7.80
# 6                               83.2                       5.87
# 7                               80.6                       7.07
# 8                               82.2                       6.40
# 9                               81.7                       7.23
# 10                              82.1                       7.22
# 11                              75.4                       5.12
# 12                              74.1                       5.99
# 13                              75.9                       5.97
# 14                              81.7                       7.23
# 15                              82.2                       6.40
# 16                              68.5                       5.28
# 17                              81.3                       5.87
# 18                              80.6                       7.07
# 19                              82.6                       7.56
# 20                              81.9                       7.12
# 21                              74.7                       5.13
# 22                              70.7                       4.15
# 23                              75.4                       5.12
# 24                              78.8                       6.94
# 25                              67.3                       3.57
# 26                              78.8                       6.94
# 27                              80.5                       7.09
# 28                              83.2                       5.87
# 29                              78.8                       6.94
# 30                              75.4                       5.51
# 31                              75.4                       5.12
# 32                              80.4                       6.86
# 33                              78.8                       6.94
# 34                              81.8                       6.66
# 35                              73.9                       6.37
# 36                              82.6                       7.56
# 37                              80.4                       7.16
# 38                              56.3                       4.81
# 39                              82.7                       6.38
# 40                              78.8                       6.94
# 41                              78.8                       6.94
# 42                              69.5                       5.54
# 43                              76.4                       6.46
#
#    Cost of a monthly gym membership(City)      Continent
# 0                                  £34.90         Europe
# 1                                  £41.66      Australia
# 2                                  £25.74         Europe
# 3                                  £37.31         Europe
# 4                                  £32.53         Europe
# 5                                  £35.23         Europe
# 6                                  £55.87           Asia
# 7                                  £26.11         Europe
# 8                                  £37.80         Europe
# 9                                  £31.04  North America
# 10                                 £36.89      Australia
# 11                                 £38.62           Asia
# 12                                 £50.03           Asia
# 13                                 £22.45  South America
# 14                                 £32.64  North America
# 15                                 £34.54         Europe
# 16                                 £29.94           Asia
# 17                                 £43.03           Asia
# 18                                 £39.01         Europe
# 19                                 £70.00         Europe
# 20                                 £58.31           Asia
# 21                                 £16.97    Europe/Asia
# 22                                 £23.25         Africa
# 23                                 £34.76           Asia
# 24                                 £32.00  North America
# 25                                 £19.54           Asia
# 26                                 £46.27  North America
# 27                                 £37.35         Europe
# 28                                 £70.82           Asia
# 29                                 £41.14  North America
# 30                                 £57.95           Asia
# 31                                 £44.68           Asia
# 32                                 £25.34         Europe
# 33                                 £65.13  North America
# 34                                 £35.93         Europe
# 35                                 £16.07  South America
# 36                                 £73.11         Europe
# 37                                 £42.71         Europe
# 38                                 £24.28         Africa
# 39                                 £53.49         Europe
# 40                                 £65.99  North America
# 41                                 £64.66  North America
# 42                                 £31.40         Europe
# 43                                 £41.99  North America

# %%
df = df.drop(columns=['City'])

# %%
df = df.rename(columns={
    "Obesity levels(Country)": "Obesity_level",
    "Life expectancy(years) (Country)": "Life_expectancy",
    "Happiness levels(Country)": "Happiness_level",
    "Cost of a monthly gym membership(City)": "Gym_membership",
})

# %%
df
# Out:
#    Obesity_level  Life_expectancy  Happiness_level Gym_membership  \
# 0         20.40%             81.2             7.44         £34.90
# 1         29.00%             82.1             7.22         £41.66
# 2         20.10%             81.0             7.29         £25.74
# 3         20.60%             81.8             7.35         £37.31
# 4         19.70%             79.8             7.64         £32.53
# 5         22.20%             80.4             7.80         £35.23
# 6          4.30%             83.2             5.87         £55.87
# 7         22.30%             80.6             7.07         £26.11
# 8         23.80%             82.2             6.40         £37.80
# 9         29.40%             81.7             7.23         £31.04
# 10        29.00%             82.1             7.22         £36.89
# 11         6.20%             75.4             5.12         £38.62
# 12        10.00%             74.1             5.99         £50.03
# 13        28.30%             75.9             5.97         £22.45
# 14        29.40%             81.7             7.23         £32.64
# 15        23.80%             82.2             6.40         £34.54
# 16         6.90%             68.5             5.28         £29.94
# 17         4.70%             81.3             5.87         £43.03
# 18        22.30%             80.6             7.07         £39.01
# 19        19.50%             82.6             7.56         £70.00
# 20        26.10%             81.9             7.12         £58.31
# 21        32.10%             74.7             5.13         £16.97
# 22        32.00%             70.7             4.15         £23.25
# 23         6.20%             75.4             5.12         £34.76
# 24        36.20%             78.8             6.94         £32.00
# 25         3.90%             67.3             3.57         £19.54
# 26        36.20%             78.8             6.94         £46.27
# 27        25.30%             80.5             7.09         £37.35
# 28         4.30%             83.2             5.87         £70.82
# 29        36.20%             78.8             6.94         £41.14
# 30         6.20%             75.4             5.51         £57.95
# 31         6.20%             75.4             5.12         £44.68
# 32        22.10%             80.4             6.86         £25.34
# 33        36.20%             78.8             6.94         £65.13
# 34        21.60%             81.8             6.66         £35.93
# 35        22.10%             73.9             6.37         £16.07
# 36        19.50%             82.6             7.56         £73.11
# 37        27.80%             80.4             7.16         £42.71
# 38        28.30%             56.3             4.81         £24.28
# 39        19.90%             82.7             6.38         £53.49
# 40        36.20%             78.8             6.94         £65.99
# 41        36.20%             78.8             6.94         £64.66
# 42        23.10%             69.5             5.54         £31.40
# 43        28.90%             76.4             6.46         £41.99
#
#         Continent
# 0          Europe
# 1       Australia
# 2          Europe
# 3          Europe
# 4          Europe
# 5          Europe
# 6            Asia
# 7          Europe
# 8          Europe
# 9   North America
# 10      Australia
# 11           Asia
# 12           Asia
# 13  South America
# 14  North America
# 15         Europe
# 16           Asia
# 17           Asia
# 18         Europe
# 19         Europe
# 20           Asia
# 21    Europe/Asia
# 22         Africa
# 23           Asia
# 24  North America
# 25           Asia
# 26  North America
# 27         Europe
# 28           Asia
# 29  North America
# 30           Asia
# 31           Asia
# 32         Europe
# 33  North America
# 34         Europe
# 35  South America
# 36         Europe
# 37         Europe
# 38         Africa
# 39         Europe
# 40  North America
# 41  North America
# 42         Europe
# 43  North America

# %%
df_obesity.columns = df_obesity.columns.str.strip().str.lower()
df.columns = df.columns.str.strip().str.lower()

# %%
df_obesity
# Out:
#                  continent  year gender   bmi
# 0                   Europe  1997      M  15.8
# 1          Western Pacific  1991      N  38.8
# 2                   Africa  2000      M   0.9
# 3          Western Pacific  1992      F   2.6
# 4    Eastern Mediterranean  2021      M  28.3
# ..                     ...   ...    ...   ...
# 994                 Europe  2016      M  24.7
# 996                 Europe  1995      N  16.5
# 997                 Africa  1998      N   1.4
# 998  Eastern Mediterranean  1991      N  24.0
# 999                 Africa  2003      N  24.7
#
# [941 rows x 4 columns]

# %%
#data = pd.merge(df_obesity, df, on=['continent'], how='inner')

# %%
#data.continent.unique()/ output = ['Europe', 'Africa']

# %% [markdown]
# Have to do few more changes like:
#
#
# continents names are different in both the dfs
#
# In df
# *   North America : Americas
# * South America   : Americas
# * Europe/Asia     : Asia
#
# In df_obesity:
# * Western Pacific : Australia
# * Eastern Mediterranean : Europe
# * South-East Asia : Asia

# %%
df.continent = df.continent.replace({'North America': 'Americas', 'South America': 'Americas', 'Europe/Asia': 'Asia'})

# %%
df_obesity.continent = df_obesity.continent.replace({'Western Pacific': 'Australia', 'Eastern Mediterranean': 'Europe', 'South-East Asia': 'Asia'})
# Out:
# /tmp/ipython-input-182/616065586.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesity.continent = df_obesity.continent.replace({'Western Pacific': 'Australia', 'Eastern Mediterranean': 'Europe', 'South-East Asia': 'Asia'})

# %%
df.continent.unique()
# Out:
# array(['Europe', 'Australia', 'Asia', 'Americas', 'Africa'], dtype=object)

# %%
df_obesity.continent.unique()
# Out:
# array(['Europe', 'Australia', 'Africa', 'Americas', 'Asia'], dtype=object)

# %%
df_new = df.drop_duplicates(subset=['continent'])
data = df_obesity.merge(df_new, on='continent', how='left', validate='many_to_one')
data
# Out:
#      continent  year gender   bmi obesity_level  life_expectancy  \
# 0       Europe  1997      M  15.8        20.40%             81.2
# 1    Australia  1991      N  38.8        29.00%             82.1
# 2       Africa  2000      M   0.9        32.00%             70.7
# 3    Australia  1992      F   2.6        29.00%             82.1
# 4       Europe  2021      M  28.3        20.40%             81.2
# ..         ...   ...    ...   ...           ...              ...
# 936     Europe  2016      M  24.7        20.40%             81.2
# 937     Europe  1995      N  16.5        20.40%             81.2
# 938     Africa  1998      N   1.4        32.00%             70.7
# 939     Europe  1991      N  24.0        20.40%             81.2
# 940     Africa  2003      N  24.7        32.00%             70.7
#
#      happiness_level gym_membership
# 0               7.44         £34.90
# 1               7.22         £41.66
# 2               4.15         £23.25
# 3               7.22         £41.66
# 4               7.44         £34.90
# ..               ...            ...
# 936             7.44         £34.90
# 937             7.44         £34.90
# 938             4.15         £23.25
# 939             7.44         £34.90
# 940             4.15         £23.25
#
# [941 rows x 8 columns]

# %%
data.isna().sum()
# Out:
# continent          0
# year               0
# gender             0
# bmi                0
# obesity_level      0
# life_expectancy    0
# happiness_level    0
# gym_membership     0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
plt.figure(figsize=(12,6))

# %% [markdown]
# **“Obesity levels vary significantly across continents.”**

# %%
sns.barplot(data=data, x='continent', y='bmi')

plt.xticks(rotation=45)
plt.title("Average BMI by Continent")
plt.xlabel("Continent")
plt.ylabel("Average BMI")

plt.show()

# %% [markdown]
# **“Continents with lower obesity levels tend to show higher happiness levels and healthier living conditions.”**

# %%
avg_data = data.groupby('continent')[['bmi', 'happiness_level']].mean().reset_index()

# %%
avg_data
# Out:
#    continent        bmi  happiness_level
# 0     Africa   7.822010             4.15
# 1   Americas  19.834615             7.23
# 2       Asia   4.251163             5.87
# 3  Australia  32.279310             7.22
# 4     Europe  18.748747             7.44

# %%
plt.figure(figsize=(12,6))

avg_data.set_index('continent')[['bmi', 'happiness_level']].plot(kind='bar')

plt.title("Average BMI vs Happiness Level by Continent")
plt.ylabel("Average Value")
plt.xticks(rotation=45)
plt.legend(["BMI", "Happiness Level"])

plt.show()

# %% [markdown]
# According to the data, the hypothesis 1 "Continents with lower obesity levels tend to show higher happiness levels" is rejected.
# But, we can see that the top 3 countries with higer BMI = higer Happines Level.

# %%
plt.figure(figsize=(8,6))

sns.regplot(data=data, x='bmi', y='happiness_level')

plt.title("BMI vs Happiness Level")
plt.xlabel("BMI")
plt.ylabel("Happiness Level")

plt.show()

# %% [markdown]
# **BMI VS LIfe Expectancy**

# %%
plt.figure(figsize=(8,6))

sns.regplot(data=data, x='bmi', y='life_expectancy')

plt.title("BMI vs Life Expectancy")
plt.xlabel("BMI")
plt.ylabel("Life Expectancy")

plt.show()

# %%
sns.countplot(data=data, x='continent', hue='gender')

plt.xticks(rotation=45)
plt.title("Observations per Continent by Gender")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=data, x="continent", y="bmi")
plt.xticks(rotation=45)
plt.show()

# %%
data.groupby("continent")["bmi"].mean()
# Out:
# continent
# Africa        7.822010
# Americas     19.834615
# Asia          4.251163
# Australia    32.279310
# Europe       18.748747
# Name: bmi, dtype: float64

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog=data["bmi"], groups=data["continent"], alpha=0.05)
print(tukey)
# Out:
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
#   group1    group2  meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------
#    Africa  Americas  12.0126    0.0   8.2907  15.7345   True
#    Africa      Asia  -3.5708 0.4614  -9.4612   2.3195  False
#    Africa Australia  24.4573    0.0  20.8473  28.0673   True
#    Africa    Europe  10.9267    0.0   7.8662  13.9873   True
#  Americas      Asia -15.5835    0.0 -21.6422  -9.5247   True
#  Americas Australia  12.4447    0.0   8.5661  16.3233   True
#  Americas    Europe  -1.0859 0.9044  -4.4591   2.2873  False
#      Asia Australia  28.0281    0.0  22.0375  34.0188   True
#      Asia    Europe  14.4976    0.0   8.8211  20.1741   True
# Australia    Europe -13.5306    0.0 -16.7799 -10.2812   True
# ------------------------------------------------------------

# %%
p_matrix = pd.DataFrame(np.ones((len(continents), len(continents))),
                        index=continents, columns=continents)

# %%
for row in tukey.summary().data[1:]:
    g1, g2, meandiff, p_adj, lower, upper, reject = row
    p_matrix.loc[g1, g2] = p_adj
    p_matrix.loc[g2, g1] = p_adj

# %%
p_matrix = p_matrix.astype(float)
p_matrix
# Out:
#            Africa  Americas    Asia  Australia  Europe
# Africa     1.0000    0.0000  0.4614        0.0  0.0000
# Americas   0.0000    1.0000  0.0000        0.0  0.9044
# Asia       0.4614    0.0000  1.0000        0.0  0.0000
# Australia  0.0000    0.0000  0.0000        1.0  0.0000
# Europe     0.0000    0.9044  0.0000        0.0  1.0000

# %%
binary_matrix = p_matrix.map(lambda p: 1 if p < 0.05 else 0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

cmap = ListedColormap(["orange", "lightblue"])

plt.figure(figsize=(10, 8))
sns.heatmap(binary_matrix,
            annot=p_matrix.round(3),
            fmt="",
            cmap=cmap,
            cbar=False,
            linewidths=5,
            linecolor="black")

plt.title("Significance Matrix (Blue = Significant, Orange = Not Significant)")
plt.show()
